# %% [markdown]
# <a href="https://colab.research.google.com/github/JoelTipape/FINANCIAL-INCLUSION-IN-E.AFRICA-PROJECT/blob/main/FINANCIAL_INCLUSION_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Financial Inclusion Analysis in Kenya, Tanzania, Uganda and Rwanda

# %% [markdown]
# ## Defining the question

# %% [markdown]
# ### Introduction

# %% [markdown]
# Financial Inclusion remains one of the main obstacles to economic and human development in Africa. For example, across Kenya, Rwanda, Tanzania, and Uganda only 9.1 million adults (or 13.9% of the adult population) have access to or use a commercial bank account.
#
# The research problem is to figure out how we can predict which individuals are most likely to have or use a bank account. Your solution will help provide an indication of the state of financial inclusion in Kenya, Rwanda, Tanzania, and Uganda, while providing insights into some of the key demographic factors that might drive individuals’ financial outcomes.

# %% [markdown]
# ### a) Specifying the Data Analytic Question

# %% [markdown]
# #### Main question

# %% [markdown]
# The aim of the project is to figure out how we can predict which individuals are most likely to have or use a bank account.

# %% [markdown]
# #### Research questions

# %% [markdown]
# 1. What are the common factors  that make people have or lack bank accounts?
# 2. Which factors are common to all?
#
# I will use Exploratory Data Analysis to answer the research questions.

# %% [markdown]
# ### b) Defining the Metric for Success

# %% [markdown]
# For this project to be successful I should aim to do the following:
# 1. Find and outline the common factors that make people have or lack bank accounts.
# 2. Find and outline the factors that are common to all the countries.

# %% [markdown]
# ### c) Understanding the context

# %% [markdown]
# Financial Inclusion remains one of the main obstacles to economic and human development in Africa. For example, across Kenya, Rwanda, Tanzania, and Uganda only 9.1 million adults (or 13.9% of the adult population) have access to or use a commercial bank account.
#
# Traditionally, access to bank accounts has been regarded as an indicator of financial inclusion. Despite the proliferation of mobile money in Africa and the growth of innovative fintech solutions, banks still play a pivotal role in facilitating access to financial services. Access to bank accounts enables households to save and facilitate payments while also helping businesses build up their credit-worthiness and improve their access to other financial services. Therefore, access to bank accounts is an essential contributor to long-term economic growth.

# %% [markdown]
# ### d) Recording the experimental design

# %% [markdown]
# The following are the steps that we will take to conduct this project. They are listed below:
#
#
# 1. Loading the required libraries
# 2. Loading the data set
# 3. Check the data
# 4. Data preparation
# 5. Validate the data
# 6. Performing Exploratory Data Analysis (EDA)
# 7. Fit the data
# 8. Draw conclusions
# 9. Make recommendations

# %% [markdown]
# ### e) Data Relevance

# %% [markdown]
# The research problem is to figure out how we can predict which individuals are most likely to have or use a bank account. Your solution will help provide an indication of the state of financial inclusion in Kenya, Rwanda, Tanzania, and Uganda, while providing insights into some of the key demographic factors that might drive individuals’ financial outcomes.

# %% [markdown]
# # Importing Libraries and the Data set

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("https://bit.ly/FinancialDataset") #Uploading the dataset
df
# Out:
#       country  year       uniqueid Has a Bank account Type of Location  \
# 0       Kenya  2018     uniqueid_1                Yes            Rural
# 1       Kenya  2018     uniqueid_2                 No            Rural
# 2       Kenya  2018     uniqueid_3                Yes            Urban
# 3       Kenya  2018     uniqueid_4                 No            Rural
# 4       Kenya  2018     uniqueid_5                 No            Urban
# ...       ...   ...            ...                ...              ...
# 23519  Uganda  2018  uniqueid_2113                 No            Rural
# 23520  Uganda  2018  uniqueid_2114                 No            Rural
# 23521  Uganda  2018  uniqueid_2115                 No            Rural
# 23522  Uganda  2018  uniqueid_2116                 No            Urban
# 23523  Uganda  2018  uniqueid_2117                 No            Rural
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# ...

# %% [markdown]
# # Missing data within the dataset

# %%
df.isnull()   #check for missing values in the dataset
df.fillna(0)  #fill in the missing values with zero
# Out:
#       country  year       uniqueid Has a Bank account Type of Location  \
# 0       Kenya  2018     uniqueid_1                Yes            Rural
# 1       Kenya  2018     uniqueid_2                 No            Rural
# 2       Kenya  2018     uniqueid_3                Yes            Urban
# 3       Kenya  2018     uniqueid_4                 No            Rural
# 4       Kenya  2018     uniqueid_5                 No            Urban
# ...       ...   ...            ...                ...              ...
# 23519  Uganda  2018  uniqueid_2113                 No            Rural
# 23520  Uganda  2018  uniqueid_2114                 No            Rural
# 23521  Uganda  2018  uniqueid_2115                 No            Rural
# 23522  Uganda  2018  uniqueid_2116                 No            Urban
# 23523  Uganda  2018  uniqueid_2117                 No            Rural
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# ...

# %% [markdown]
# # Univariate Analysis

# %%
##Pie chart showing percentage of those who have bank accounts and those who don't in all the countries
df.groupby("Has a Bank account")["Has a Bank account"].count().plot.pie(autopct='%.2f',figsize=(5,5))

# %%
# Plot to show respondent age 
sns.histplot(df['Respondent Age'], bins=10)
plt.title('Respondent age distribution')
# Out:
# Text(0.5, 1.0, 'Respondent age distribution')

# %%
df['Respondent Age'].skew()
# Out:
# 0.8418012375387167

# %% [markdown]
# The Respondent age is moderately positively skewed.

# %%
# Check for outliers
df['Respondent Age'].kurt()
# Out:
# 0.10110811880734305

# %% [markdown]
# The data is platykurtic since there are no outliers

# %%
# Plot Household size distribution
sns.distplot(df['household_size'], bins=10)
plt.title('Household Size Distribution')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Household Size Distribution')

# %%
# Check for skewness
df['household_size'].skew()
# Out:
# 0.977652354434429

# %%
# Check for kurtosis
df['household_size'].kurt()
# Out:
# 1.1581542795310726

# %% [markdown]
# The Household size distribution has a moderate positive skewness.
# The household size distribution is playkurtic meaning there are no outliers.

# %% [markdown]
# # Bivariate Analysis

# %%
# Determine correlation between Respondent age and Household size
sns.pairplot(df[['household_size','Respondent Age']])
plt.title('Respondent Age vs Household Size')
plt.show()

# %%
df['Respondent Age'].corr(df['household_size'])
# Out:
# -0.1197092971464233

# %% [markdown]
# From the scatter plot and pearsons correlation, there is a very weak negative correlation between Respondent age and Household size.

# %% [markdown]
# # Multivariate Analysis

# %%
# Investigate relationship between country, level of education and bank account status
country_edu = pd.crosstab(index=[df['Has a Bank account'],df['country']], columns=df['Level of Educuation'])

country_edu.loc[('No', slice(None)),:].plot(kind='bar', figsize=(12,10))
plt.xticks([0,1,2,3], labels=['Kenya','Rwanda','Tanzania','Uganda'], rotation=0)
plt.xlabel('Education distribution per country')
plt.title('Respondents with no bank accounts')

country_edu.loc[('Yes', slice(None)),:].plot(kind='bar', figsize=(12,10))
plt.xticks([0,1,2,3], labels=['Kenya','Rwanda','Tanzania','Uganda'], rotation=0)
plt.xlabel('Education distribution per country')
plt.title('Respondents with bank accounts')
# Out:
# Text(0.5, 1.0, 'Respondents with bank accounts')

# %% [markdown]
# For each country, the level of education with the highest number of respondents with bank accounts:
# - Kenya : Secondary Education
# - Rwanda : Primary education
# - Tanzania : Primary/Tertiary Education
# - Uganda : Secondary education
#
# In all countries, the level of education with the highest number of respondents with no bank accounts is primary education.

# %%
# Investigate relationship between gender, type of job and bank account status
gender_job = pd.crosstab(index=[df['Has a Bank account'],df['gender_of_respondent']], columns=df['Type of Job'])

gender_job.loc[('No', slice(None)),:].plot(kind='bar', figsize=(12,10))
plt.xticks([0,1], labels=['Female', 'Male'], rotation=0)
plt.xlabel('Job type distribution per gender')
plt.title('Respondents with no bank accounts')
plt.legend(loc='upper right')

gender_job.loc[('Yes', slice(None)),:].plot(kind='bar', figsize=(12,10))
plt.xticks([0,1], labels=['Female', 'Male'], rotation=0)
plt.xlabel('Job type distribution per gender')
plt.title('Respondents with bank accounts')
plt.legend(loc='upper right')

# %% [markdown]
# For both women and men, the highest propotion of respondents with the following types of jobs have bank accounts:
# - Self employed
# - Farming and fishing
# - Formally employed private
# - Informally employed

# %%
# Investigate relationship between cell access, location and bank account status
loc_cell = pd.crosstab(index=[df['Has a Bank account'],df['Type of Location']], columns=df['Cell Phone Access'])

loc_cell.loc[('No', slice(None)),:].plot(kind='bar', figsize=(12,10))
plt.xticks([0,1], labels=['Rural','Urban'], rotation=0)
plt.xlabel('Cell phone access distribution per location')
plt.title('Respondents with no bank accounts')
plt.legend(loc='upper right')

loc_cell.loc[('Yes', slice(None)),:].plot(kind='bar', figsize=(12,10))
plt.xticks([0,1], labels=['Rural','Urban'], rotation=0)
plt.xlabel('Cell phone access distribution per location')
plt.title('Respondents with bank accounts')
plt.legend(loc='upper right')

# %% [markdown]
# Access to a cell phone and individuals with bank accounts is almost similar as per the distributions.

# %% [markdown]
# # Conclusion

# %% [markdown]
# 1. The percentage of individuals with no bank accounts is extremely high in comparison to those that have a bank account. 85% of all respondents have no bank accounts.
#
# 2. Factors such as gender, job type, location as well as access to a cellphone
# having a significant impact on whether an individual has an account or not.
